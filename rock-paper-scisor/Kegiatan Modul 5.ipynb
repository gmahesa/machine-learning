# %% [markdown]
# # **Kegiatan Modul 5**

# %% [markdown]
# Kali ini anda dibebaskan untuk memilih satu dataset untuk kasus klasifikasi citra menggunakan CNN Deep Learning. Dari dataset tersebut anda ditugaskan membangun model CNN dengan ketentuan skema pengujian dataset Balance, Imbalance, dan Augmentasi Balance. Eksplorasi sebanyak banyaknya untuk membangun model CNN terbaik anda. Perhatikan poin-poin penilaian berikut untuk lebih jelasnya.
#
# <br>
#
# **Poin penilaian :**
#
# * Melakukan skema pengujian model menggunakan dataset sesuai ketentuan diatas dan menjelaskan sedetail mungkin kepada asisten semua informasi penting yang anda dapatkan kemudian berikan kesimpulan finalnya. **15 poin untuk setiap skema pengujian**
# * Melakukan ujicoba model dengan menerapkan materi pada modul-modul sebelumnya.  ***bisa pilih salah satu atau semuanya***
#   * Membangun CNN model sederhana tanpa hyperparameter optimization dan regularization **5 poin**
#   * Membangun CNN model yang menerapkan regularization **5 poin**
#   * Membangun CNN model yang menerapkan hiperparameter tuning **10 poin**
# * Pada skema dataset `augmentasi balance` anda WAJIB menerapkan minimal 3 proses augmentasi sederhana *(flip, reshape, resize, rotate, miror, cut, shear, zoom)* seperti yang telah dijelaskan di materi modul: **10 poin**
# * Menjelaskan hasil evaluasi setiap model kepada asisten. Evaluasi berupa nilai acc, f-measure, recall, precision, weighted precision, weighted recall dan balance acc. **5 poin**
# * Melakukan visualisasi model seperti grafik loss, grafik accuracy, grafik confusion matrix. **5 poin**
# * Menggunakan Tensorboard **10 poin**
# * Menampilkan matriks evaluasi yang lengkap **5 poin**
# * Menampilkan visualisasi dari matriks evaluasi **10 poin**
# * Melakukan prediksi unseen dataset **10 poin**
#
# <br>
#
# **EKSTRA POIN**
# * Dapat menerapkan proses advanced augmentation pada skema dataset `augmentasi balance` anda seperti :
#   * Salt noise **15 poin**
#   * Clahe **15 poin**
#   * Usuyama **15 poin**
#   * dst. **15 poin**
# * Hasil accuracy model terbaik > 70% **5 poin** *
# * Hasil accuracy model terbaik >= 80% **10 poin** *
# * Hasil accuracy model terbaik >= 85% **15 poin** *
# * Hasil accuracy model terbaik >= 90% **25 poin** *
# * Bagi anda yang dapat menjelaskan pekerjaan anda dengan baik dengan tanpa adanya plagiasi dalam program anda anda berhak mendapat ekstra poin. **10 poin**
#
# <br>
#
# **PUNISHMENT**
# * Struktur program dan model CNN sama **-50 poin**
# * Struktur program, model dan dataset sama persis **-55 poin**
# * Model dan dataset sama persis **-50 poin**
# * Model CNN sama persis **-45 poin**
#
#
# \* *Pilih salah satu berdasarkan nilai akurasi terbaik*

# %%
# Tulis Program Anda Disini!
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import os
# os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/Colab Notebooks/kaggle"

# %% [markdown]
# # **WORK SPACE**

# %%
# %cd /content/drive/My Drive/Colab Notebooks/modul5
# Out:
# /content/drive/My Drive/Colab Notebooks/modul5

# %%
# !kaggle datasets download -d drgfreeman/rockpaperscissors

# %%
# Ekstrak file dataset dan hapus file zip dataset agar tidak memakan banyak tempat.
# !unzip \*.zip &> /dev/null && rm *.zip

# %%
# %mkdir RPS/dataset/

# %%
# %mv -t RPS/dataset paper rock scissors

# %%
# pip install splitfolders

# %% [markdown]
# # **SPLIT DATASET (TRAIN 79%, VAL 20%, TEST 1%)**

# %%
# import splitfolders
# splitfolders.ratio('RPS/dataset/', output='RPS/', seed=1337, ratio=(.79, .20, .01))

# %%
# base_dir = 'RPS'

# train_dir = os.path.join(base_dir, 'train')
# val_dir = os.path.join(base_dir, 'val')

# %%
# import cv2
# import numpy as np

# # Gather data train
# train_data = []
# train_label = []
# for r, d, f in os.walk(train_dir):
#     for file in f:
#         if ".png" in file:
#             imagePath = os.path.join(r, file)
#             image = cv2.imread(imagePath)
#             image = cv2.resize(image, (150,150))
#             train_data.append(image)
#             label = imagePath.split(os.path.sep)[-2]
#             train_label.append(label)

# train_data = np.array(train_data)
# train_label = np.array(train_label)

# %%
# # Gather data validation
# val_data = []
# val_label = []
# for r, d, f in os.walk(val_dir):
#     for file in f:
#         if ".png" in file:
#             imagePath = os.path.join(r, file)
#             image = cv2.imread(imagePath)
#             image = cv2.resize(image, (150,150))
#             val_data.append(image)
#             label = imagePath.split(os.path.sep)[-2]
#             val_label.append(label)

# val_data = np.array(val_data)
# val_label = np.array(val_label)

# %%
# print("Train Data = ", train_data.shape)
# print("Train Label = ", train_label.shape)
# print("Validation Data = ", val_data.shape)
# print("Validation Label = ", val_label.shape)

# %%
import os

img_folder_path = 'RPS/train/rock'
dirListing = os.listdir(img_folder_path)
print(len(dirListing))

img_folder_path = 'RPS/train/paper'
dirListing = os.listdir(img_folder_path)
print(len(dirListing))

img_folder_path = 'RPS/train/scissors'
dirListing = os.listdir(img_folder_path)
print(len(dirListing))
# Out:
# 573
# 562
# 592

# %%
# # Normalisasi dataset
# print("Data sebelum di-normalisasi ", train_data[0][0][0])

# x_train = train_data.astype('float32') / 255.0
# x_val = val_data.astype('float32') / 255.0
# print("Data setelah di-normalisasi ", x_train[0][0][0])

# %%
# # Transformasi label encoder
# from sklearn.preprocessing import LabelEncoder

# print("Label sebelum di-encoder ", train_label[200:205], train_label[600:605], train_label[1400:1405])

# lb = LabelEncoder()
# y_train = lb.fit_transform(train_label)
# y_val = lb.fit_transform(val_label)

# print("Label setelah di-encoder ", y_train[200:205], y_train[600:605], y_train[1400:1405])

# %% [markdown]
# # **IMAGE GENERATOR**

# %%
train_path = "RPS/train"
test_path  = "RPS/test"
val_path   = "RPS/val"

# %%
# TULIS KODE ANDA DISINI
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_path,
                                                    target_size=(150, 150),
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    color_mode="rgb",
                                                    shuffle="false")

test_generator = test_datagen.flow_from_directory(test_path,
                                                  target_size=(150, 150),
                                                  batch_size=32,
                                                  class_mode='categorical',
                                                  color_mode="rgb",
                                                  shuffle="false")

val_generator = val_datagen.flow_from_directory(val_path,
                                                target_size=(150, 150),
                                                batch_size=32,
                                                class_mode='categorical',
                                                color_mode="rgb",
                                                shuffle="false")
# Out:
# Found 1727 images belonging to 3 classes.
# Found 24 images belonging to 3 classes.
# Found 437 images belonging to 3 classes.

# %%
# IMPORT SEMUA PAKET YANG ANDA PERLUKAN UNTUK MENDEFINISIKAN MODEL DISINI
import tensorflow as tf
from tensorflow import keras
from keras.optimizers import Adam
from keras import models
from keras.models import Sequential
from keras import layers
from keras.layers import InputLayer
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout
import matplotlib.pyplot as plt

# import time

# %% [markdown]
# # **IMBALANCE DATA TRAIN**

# %%
# DEFINISIKAN MODEL ANDA DISINI
# Feature Extraction Layer
model = models.Sequential()
model.add(InputLayer(input_shape=[150,150,3]))

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

keras.layers.Dropout(rate=0.2)

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

keras.layers.Dropout(rate=0.5)

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2, padding='same'))

model.add(BatchNormalization())

model.add(Flatten())

# %%
# Fully Connected Layer
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
# TULIS CODE UNTUK MENAMPILKAN SUMMARY DARI ARSITEKTUR MODEL ANDA DISINI
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 75, 75, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 38, 38, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 19, 19, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 32)          9248
# ...

# %%
model.compile(optimizer=Adam(lr=0.0001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# TULIS CODE UNTUK TRAINING DISINI
epoch = 50

Imbalance_H = model.fit_generator(train_generator, steps_per_epoch=32, validation_data=val_generator, epochs=epoch, verbose=1)

model.save("model_imbalance.h5")
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 32/32 [==============================] - 112s 4s/step - loss: 1.0986 - accuracy: 0.3398 - val_loss: 1.0986 - val_accuracy: 0.3249
# Epoch 2/50
# 32/32 [==============================] - 9s 288ms/step - loss: 1.0981 - accuracy: 0.4081 - val_loss: 1.0985 - val_accuracy: 0.3432
# Epoch 3/50
# 32/32 [==============================] - 9s 285ms/step - loss: 1.0936 - accuracy: 0.6916 - val_loss: 1.0976 - val_accuracy: 0.3478
# Epoch 4/50
# 32/32 [==============================] - 9s 292ms/step - loss: 1.0703 - accuracy: 0.8434 - val_loss: 1.0913 - val_accuracy: 0.5355
# Epoch 5/50
# ...

# %%
# from keras.models import load_model

# model = load_model("model_imbalance.h5")

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score

# %%
num_of_train_samples = 1727   
batch_size = 32

# %%
Y_pred_train = model.predict(train_generator, num_of_train_samples // batch_size+1)
Y_pred_val = model.predict(val_generator, num_of_train_samples // batch_size+1)
Y_pred_test = model.predict(test_generator, num_of_train_samples // batch_size+1)

# %%
import numpy as np
y_pred_train = np.argmax(Y_pred_train, axis=1)
y_pred_val = np.argmax(Y_pred_val, axis=1)
y_pred_test = np.argmax(Y_pred_test, axis=1)

# %%
print('Classification Report Train Data')
print(classification_report(train_generator.classes, y_pred_train, target_names=train_generator.class_indices))

print('Classification Report Validation Data')
print(classification_report(val_generator.classes, y_pred_val, target_names=val_generator.class_indices))

print('Classification Report Test Data')
print(classification_report(test_generator.classes, y_pred_test, target_names=test_generator.class_indices))

accuracy_score(test_generator.classes, y_pred_test)
# Out:
# Classification Report Train Data
#               precision    recall  f1-score   support
#
#        paper       0.37      0.37      0.37       562
#         rock       0.35      0.35      0.35       573
#     scissors       0.36      0.36      0.36       592
#
#     accuracy                           0.36      1727
#    macro avg       0.36      0.36      0.36      1727
# weighted avg       0.36      0.36      0.36      1727
#
# Classification Report Validation Data
#               precision    recall  f1-score   support
#
#        paper       0.35      0.37      0.36       142
#         rock       0.31      0.30      0.31       145
#     scissors       0.31      0.31      0.31       150
#
#     accuracy                           0.32       437
#    macro avg       0.32      0.33      0.33       437
# weighted avg       0.32      0.32      0.32       437
#
# Classification Report Test Data
#               precision    recall  f1-score   support
#
# ...

# %%
# TULIS CODE UNTUK EVALUASI MODEL DISINI
test_score = model.evaluate_generator(test_generator, 32)

print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100)) 
print("[INFO] Loss: ",test_score[0])
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 32 batches). You may need to use the repeat() function when building your dataset.
# [INFO] accuracy: 100.00%
# [INFO] Loss:  0.0014545683516189456

# %%
# TULIS CODE UNTUK PLOT EVALUASI MODEL DISINI
plt.style.use("ggplot")
plt.figure()
#plt.axis(0,25,0,8)
plt.plot(np.arange(0, epoch), Imbalance_H.history["loss"], label="train_loss")
plt.plot(np.arange(0, epoch), Imbalance_H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, epoch), Imbalance_H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, epoch), Imbalance_H.history["val_accuracy"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # **BALANCE DATA TRAIN** Under Sampling

# %%
# %pip install imbalanced-learn

# %%
# check version number
import imblearn
from imblearn.under_sampling import RandomUnderSampler
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
rus = RandomUnderSampler(random_state=0)
train_resample, train_class_resample = rus.fit_resample(train_generator, train_generator.classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-71c42fd60caf> in <module>()
# ----> 1 rus = RandomUnderSampler(random_state=0)
#       2 train_resample, train_class_resample = rus.fit_resample(train_generator, train_generator.classes)
#
# NameError: name 'RandomUnderSampler' is not defined

# %%
# IMPORT SEMUA PAKET YANG ANDA PERLUKAN UNTUK MENDEFINISIKAN MODEL DISINI
import tensorflow as tf
from tensorflow import keras
from keras.optimizers import Adam
from keras import models
from keras.models import Sequential
from keras import layers
from keras.layers import InputLayer
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout
import matplotlib.pyplot as plt

# import time

# %%
ls
# Out:
#  IDC_VGG16.h5             'Modul 5 ML - Handling Overfit Problem (3).ipynb'
# 'Kegiatan Modul 5.ipynb'   README_rpc-cv-images.txt
#  model_imbalance.h5        RPS/
#  model_mobilenet.h5        rps-cv-images/

# %%
# model = tf.keras.models.load_model(
#     "IDC_VGG16.h5"
# )
model = create_model()
model.load_weights("IDC_VGG16.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7df849eee77b> in <module>()
#       2 #     "IDC_VGG16.h5"
#       3 # )
# ----> 4 model = create_model()
#       5 model.load_weights("IDC_VGG16.h5")
#
# NameError: name 'create_model' is not defined

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 75, 75, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 38, 38, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 19, 19, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 32)          9248
# ...
